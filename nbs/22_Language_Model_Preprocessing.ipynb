# %% [markdown]
# # Preparing to build a Twitter language model

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
num_words = 100
embedding_dimension = 200

# %% [markdown]
# ## Load data

# %%
from tep.dataLoader import DataLoader
dl = DataLoader()

# %%
# load tweets from file
tweets = dl.load_from_file(filename="data/tweets_1.json", ignore_retweets=True)
len(tweets)
# Out:
# 284701

# %%
# randomize tweet order
import random
random.seed(1000)
random.shuffle(tweets)

# %% [markdown]
# ## Tokenize texts

# %%
from tep.dataPreprocessor import DataPreprocessor
dp = DataPreprocessor()

# %%
# test extracting content
texts = dp.extract_content(tweets[:100])
texts
# Out:
# ['<hashtag> popovichkerr <number>   <user>   <user>   <url>',
#  ' <user>  we want to get this reported over to our quality control team and make up for that purchase .  ( <number>  /  <number> )',
#  '"the  <number> nd - order effects when electric, self - driving, software - powered cars become mainstream" <url> <url>',
#  'great event today at the harris school of public policy :  <url>',
#  ' <user>  are not they just amazing ? ',
#  'what is your biggest data challenge ?  revolutionize your <hashtag> cyber analytics at <hashtag> bhusa <allcaps>  <allcaps> <url> <url>',
#  'cat  <number> d <number>  xhp <allcaps>  delivers multi - functional solution to large estate in englan <smile>  <url> <url>',
#  'always moving the needle !  <url>',
#  ' <user>  congratulations',
#  'but they are such convincing lies .  <repeat> <url>',
#  'sheryl sandberg on cnbc <allcaps>  at  <number>  do not miss it .  <url>',
#  ' <user>  our apologies, and sorry for the trouble earlier . ',
#  ' <user>   <user>   <user>   <user>  code splitting is one way to make your app download faster .  my p  .  <repeat> <url>',
#  'visit us at the university of minnesota career fair tomorrow to learn more about our open jobs !   .  <repeat> <url>',
#  '“now you are the one doing it . ” <url> <hashtag> caregiving <hashtag> family',
#  '<url>',
#  'today we remember former xerox ceo <allcaps>  joseph c .  wilson, born on this date in  <number>  thanks for everything, joe .  <url>',
#  ' <user>   : through the gaviota hotel chain, gaesa <allcaps>  has nearly  <number>  hotel rooms, including the majority of cuba four -  and five - star hotels  <number>  /  <number> ',
#  'learn more about how to use precision current measurement to enhance eps <allcaps>  systems :  <url> .  <url>',
#  'listen to national security experts discuss future of <hashtag> missiledefense :  <url> <hashtag> def one s m d <url>',
#  ' <user>  we have attached all the price match information here for you .  it will answer any questions you may hav  .  <repeat> <url>',
#  'if you live in highland park, koreatown, downtown la <allcaps>  go <allcaps>  vote <allcaps> ',
#  ' <user>  hi andrew !  we are also looking forward for you enjoying it !  regards .   - cjc <allcaps> ',
#  'i enjoyed reminiscing about my time as an <hashtag> arkansas <hashtag> razorback football player with  <user>  .  <url>',
#  ' <user>  it appears for this event the only presale offered is the dr .  phillips center member presale .   - tc <allcaps> ',
#  '"we can use facebook, twitter, et al to snap and snark at each other or to find ourselves in others and join togeth  .  <repeat> <url>',
#  'my week on twitter 🎉 :   <number>  mentions,  <number> k mention reach,  <number>  likes,  <number>  retweets,  <number> k retweet reach .  see yours with  .  <repeat> <url>',
#  ' <user>   <user>  you are a journalist .  your job is to hate bret and tweet snotty things . ',
#  ' <user>  hi mike, sorry to hear you had that experience .  pls complete this form for follow - up :  <url> thanks, ~ debra',
#  'open enrollment is now underway .  to find a health insurance plan that works for you, log on to  .  <repeat> <url>',
#  '<hashtag> tip tuesday do not let your herbs go to waste !  combine herbs &amp ;  olive oil into ice cube trays &amp ;  freeze for later <url>',
#  '<url> <url>',
#  'joint statement with  <user>  :  the senate intelligence committee has invited james comey to testify in open &amp ;  c  .  <repeat> <url>',
#  ' <user>  should i .  ok fine',
#  'video of tesla self - driving car in action <url>',
#  'since polaris began operating over ten years ago, its helplines have received reports of  <number>  cases of human traffic  .  <repeat> <url>',
#  'when an entire swedish city needs to move (literally), lth <allcaps>  traktor &amp ;  their cat multi - processor are there to help :   .  <repeat> <url>',
#  'krewe, runner up of the cfda <allcaps>  / vogue fashion fund, designed smart frames that collect memories with intel curie :   .  <repeat> <url>',
#  'french presidential contender emmanuel macron unique love story <url> via  <user> ',
#  ' <user>  we are concerned by your comments &amp ;  would like to look into it .  can you please call us at  <number>  <number>  <number>  so we can learn more ? ',
#  ' <user>   <user>  classy',
#  ' <user>   <user>  michael, you know that they and every advertising company offers "embeds" aka account service  .  <repeat> <url>',
#  'day  <number>  of our <hashtag> summer of booz intern challenge cup pitches !  <hashtag> interns <url>',
#  ' <user>  cheers to that ian !  🍻',
#  ' <number> % support banning modifications  -  -  like bump stocks  -  -  that turn semiautomatic weapons in automatic weapons\n\n<url>',
#  ' <user>  ready for this show to be cancelled',
#  'have a condo ?  learn what your association policy may cover versus your policy :  <url> <url>',
#  ' <user>  yeah tweeted that earlier too',
#  ' <user>  : <url>',
#  'getting ready to join  <user>  &amp ;   <user>  on a tour to see memorial bridge deterioration firsthand <url>',
#  ' <user>  where are these ? ',
#  '<hashtag> mosen <allcaps>  <allcaps> candidate not headed to dnc <allcaps>  per the hometown paper .  <url>',
#  'learn about our diverse team of innovative thinkers !  visit us at <hashtag> access n b m b a a ‘ <number>  booth  <number>  and find the scienc  .  <repeat> <url>',
#  'how much land is available to grow our food ?  less than you may think .  <hashtag> wfd <allcaps>  <allcaps> <number>  <url>',
#  'ordered !  <url>',
#  'excellent !  make the most of the week ahead !  <hashtag> a v tweeps <url>',
#  'want to know more about oncommand unified manager ?  check out  <user>  latest blog on how you can use it to maximi  .  <repeat> <url>',
#  'stay tuned to watch ryder ceo <allcaps>  robert sanchez on  <user>  this morning before  <number> am .  <hashtag> new product <hashtag> economy',
#  'in undercover video, cambridge analytica exec boasted of creating the “defeat crooked hillary” campaign online .   .  <repeat> <url>',
#  'wait, what ?  god ?  <url>',
#  'to help a local family in need celebrate the holidays, our dallas sales team donated toys, clothing &amp ;  household goo  .  <repeat> <url>',
#  ' <user>  of course i do !  grew up on big daddy kane ! ',
#  ' <user>  hi there !  our commercial storyline echoes a real - life story of john valentine from the  <number> s .  hope you like it .   -  bryan',
#  'i am just a girl, standing in front of a boy, asking him to outdebate her at a fancy confab .  thus, i am hereby publi  .  <repeat> <url>',
#  ' <user>  this is the paper i rea <smile>  <url>',
#  'w /  <hashtag> graphene diverse properties, researchers are expecting functional inks &amp ;  coatings to reach the market soon :   .  <repeat> <url>',
#  ' <user>   <user>  diaper mike',
#  ' <user>  we love these shoes !  good luck and thank you for all you do to support st .  jude ! ',
#  '"dad, let pop some popcorn and turn on  <user>  ! "  -   <user>   <url>',
#  'why does jack say that he has violated the restraining order he got against corryn ? \n <hashtag> dr phil <url>',
#  'free black mirror episode :  in the not - too - distant future, you pay for everything with selfies . ',
#  ' <user>  thrilled to hear you are rejecting the "common wisdom" and using the real wisdom of evidence - backed studies ! ',
#  ' <user>   <user>  i bet she is close, judging by jess  <smile> ',
#  ' <user>  you know what would go great with your <hashtag> first car ?  free gas .  follow and dm <allcaps>  us for a little something .  <hashtag> heres to firsts',
#  'what did  <user>  &amp ;   <user>  discuss in  <user>  virtual summit yesterday ?  find out here :  <url> <hashtag> authentication',
#  'a timeline of trump flipping and flopping on daca <allcaps>  over the years :  <url>',
#  ' <user>  thanks for the feedback .  if we had the metrics in the api <allcaps> , would that make it easier ? ',
#  '<url>',
#  ' <user>   <user>  very smart moves .  i went with a volvo xc <allcaps>  <number>  because apparently safety negates a terrible in - dash interface',
#  'from those just starting out in <hashtag> stem <allcaps>  <allcaps> fields, to <hashtag> nasa <allcaps>  <allcaps> <hashtag> engineers &amp ;  <hashtag> nobel peace prize winners, read more about these  .  <repeat> <url>',
#  ' <user>   <user>  <url>',
#  'lol <hashtag> g r a m m ys <url>',
#  'poetry fans, james merrill fans, iambic pentameter fans, i give you my dad, bill pahlka .  great interview with him a  .  <repeat> <url>',
#  '"elon musk keeps trying to get me to go to burning man .  no thank you" .  what an incredible interview <url> via  <user> ',
#  ' <user>  bono .  always bono',
#  'join symantec  <user>  at <hashtag> gartner s e c .  learn about his session on the evolving cybersecurity landscape :   .  <repeat> <url>',
#  'i demand to know who sent me this hidden valley ranch xmas ornament <url>',
#  ' <user>  thank you, hunter .  we are very happy to hear you were touched by our commercial with  <user>  . ',
#  'we are giving your favorite <hashtag> live generously t - shirt a new look for a new year !  cast your vote for a fresh color :  <url>',
#  'did trump really just say that ?  <url>',
#  'joy reid of  <user>  is brilliant &amp ;  always superbly prepared .  when i am lucky enough to be on the air with her she nev <allcaps>   .  <repeat> <url>',
#  'huge .  <url>',
#  'new data shows that ar <allcaps>  agricultural producers continue to lose out under washington current restrictive trade pol  .  <repeat> <url>',
#  'whoops, sorry announcer, that karpinski of "league of conservation voters," not "league of conservative voters . " that would be news . ',
#  'i am old enough to remember when the discussion about “a spotify for news” was about an “itunes for news” .  and it is still not working  .  <repeat>',
#  'rob woodall praises ‘bicameral’ passage of tax rewrite by congress <url>',
#  '"pruitt has gone above &amp ;  beyond to be responsive to this committee .  he answered  <number>  qs during his hearing &amp ;   <number>  qs for the record"  <user> ',
#  'tx <allcaps>  gov .  just signed bill barring state contracts with firms that boycott israel .  here pros / cons on it from state -   .  <repeat> <url>',
#  'is it sacrilege to ask :  why do we need apps for computers ?  is not it fine to use the web version ?  \n <url>',
#  'amen .  <url>']

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# %%
tokenizer = Tokenizer(num_words=100, filters='"”“#$%&()*+,/=@[]^_´`‘{|}~\t\n\\')

# %%
tokenizer.fit_on_texts(texts)

# %%
len(tokenizer.word_index)
# Out:
# 729

# %%
tokenizer.word_index
# Out:
# {'!': 15,
#  '-': 10,
#  '.': 2,
#  ':': 16,
#  ';': 24,
#  '<allcaps>': 6,
#  '<hashtag>': 7,
#  '<number>': 8,
#  '<repeat>': 9,
#  '<smile>': 65,
#  '<url>': 1,
#  '<user>': 3,
#  '?': 17,
#  'a': 13,
#  'about': 34,
#  'above': 706,
#  'access': 450,
#  'account': 409,
#  'action': 354,
#  'advertising': 404,
#  'against': 556,
#  'ago': 360,
#  'agricultural': 675,
#  'ahead': 466,
#  'air': 670,
#  'aka': 408,
#  'al': 298,
#  'all': 112,
#  'also': 275,
#  'always': 66,
#  'am': 41,
#  'amazing': 189,
#  'amen': 729,
#  'amp': 23,
#  'an': 51,
#  'analytica': 488,
#  'analytics': 193,
#  'and': 20,
#  'andrew': 274,
#  'announcer': 685,
#  'answer': 265,
#  'answered': 709,
#  'any': 266,
#  'api': 593,
#  'apologies': 212,
#  'app': 217,
#  'apparently': 600,
#  'appears': 289,
#  'apps': 725,
#  'ar': 674,
#  'are': 26,
#  'arkansas': 285,
#  'as': 284,
#  'ask': 724,
#  'asking': 525,
#  'association': 430,
#  'at': 33,
#  'attached': 260,
#  'authentication': 586,
#  'automatic': 426,
#  'available': 456,
#  'b': 148,
#  'backed': 570,
#  'banning': 421,
#  'barring': 716,
#  'be': 57,
#  'because': 599,
#  'become': 184,
#  'before': 483,
#  'began': 357,
#  'bet': 572,
#  'beyond': 707,
#  'bhusa': 194,
#  'bicameral’': 699,
#  'big': 511,
#  'biggest': 190,
#  'bill': 163,
#  'black': 559,
#  'blog': 474,
#  'boasted': 490,
#  'bono': 166,
#  'booth': 452,
#  'booz': 413,
#  'born': 233,
#  'boy': 524,
#  'boycott': 719,
#  'bret': 317,
#  'bridge': 438,
#  'brilliant': 666,
#  'bryan': 520,
#  'bump': 423,
#  'burning': 631,
#  'but': 204,
#  'by': 54,
#  'c': 70,
#  'call': 399,
#  'cambridge': 487,
#  'campaign': 495,
#  'can': 52,
#  'cancelled': 428,
#  'candidate': 443,
#  'car': 132,
#  'career': 223,
#  'caregiving': 228,
#  'cars': 183,
#  'cases': 365,
#  'cast': 660,
#  'cat': 97,
#  'celebrate': 500,
#  'center': 293,
#  'ceo': 106,
#  'cfda': 380,
#  'chain': 238,
#  'challenge': 96,
#  'check': 472,
#  'cheers': 418,
#  'city': 370,
#  'cjc': 280,
#  'classy': 401,
#  'close': 573,
#  'clothing': 506,
#  'cnbc': 210,
#  'coatings': 539,
#  'code': 214,
#  'collect': 386,
#  'color': 662,
#  'combine': 336,
#  'comey': 349,
#  'comments': 397,
#  'commercial': 150,
#  'committee': 128,
#  'common': 567,
#  'company': 405,
#  'complete': 323,
#  'computers': 726,
#  'concerned': 396,
#  'condo': 429,
#  'confab': 528,
#  'congratulations': 203,
#  'congress': 703,
#  'cons': 722,
#  'conservation': 687,
#  'conservative': 688,
#  'contender': 392,
#  'continue': 677,
#  'contracts': 717,
#  'control': 176,
#  'convincing': 206,
#  'corryn': 557,
#  'course': 509,
#  'cover': 431,
#  'creating': 491,
#  'crooked': 493,
#  'cuba': 244,
#  'cube': 340,
#  'cup': 415,
#  'curie': 389,
#  'current': 109,
#  'cyber': 192,
#  'cybersecurity': 640,
#  'd': 98,
#  'daca': 590,
#  'dad': 154,
#  'daddy': 512,
#  'dallas': 502,
#  'dash': 604,
#  'data': 95,
#  'date': 234,
#  'day': 411,
#  'debra': 325,
#  'def': 259,
#  'defeat': 492,
#  'delivers': 196,
#  'demand': 642,
#  'designed': 384,
#  'deterioration': 439,
#  'diaper': 542,
#  'did': 160,
#  'discuss': 110,
#  'discussion': 690,
#  'distant': 562,
#  'diverse': 147,
#  'dm': 578,
#  'dnc': 445,
#  'do': 39,
#  'does': 551,
#  'doing': 227,
#  'donated': 504,
#  'download': 218,
#  'downtown': 272,
#  'dr': 117,
#  'driving': 92,
#  'during': 710,
#  'e': 637,
#  'each': 301,
#  'earlier': 101,
#  'easier': 594,
#  'echoes': 515,
#  'economy': 485,
#  'effects': 179,
#  'electric': 180,
#  'elon': 627,
#  'embeds': 407,
#  'emmanuel': 393,
#  'engineers': 611,
#  'englan': 200,
#  'enhance': 251,
#  'enjoyed': 281,
#  'enjoying': 278,
#  'enough': 168,
#  'enrollment': 326,
#  'entire': 368,
#  'episode': 561,
#  'eps': 252,
#  'estate': 199,
#  'et': 297,
#  'event': 93,
#  'every': 403,
#  'everything': 107,
#  'evidence': 569,
#  'evolving': 639,
#  'excellent': 464,
#  'exec': 489,
#  'expecting': 537,
#  'experience': 321,
#  'experts': 257,
#  'facebook': 296,
#  'fair': 224,
#  'family': 104,
#  'fancy': 527,
#  'fans': 86,
#  'fashion': 382,
#  'faster': 219,
#  'favorite': 655,
#  'feedback': 591,
#  'fields': 609,
#  'find': 53,
#  'fine': 130,
#  'firms': 718,
#  'first': 576,
#  'firsthand': 440,
#  'firsts': 582,
#  'five': 246,
#  'flipping': 588,
#  'flopping': 589,
#  'follow': 124,
#  'food': 458,
#  'football': 287,
#  'for': 14,
#  'form': 324,
#  'former': 229,
#  'forward': 277,
#  'four': 245,
#  'frames': 385,
#  'free': 157,
#  'freeze': 342,
#  'french': 390,
#  'fresh': 661,
#  'from': 83,
#  'front': 523,
#  'functional': 100,
#  'fund': 383,
#  'future': 111,
#  'g': 618,
#  'gaesa': 239,
#  'gartner': 636,
#  'gas': 577,
#  'gaviota': 237,
#  'generously': 656,
#  'get': 89,
#  'getting': 435,
#  'girl': 521,
#  'give': 625,
#  'giving': 654,
#  'go': 50,
#  'god': 498,
#  'gone': 705,
#  'goo': 508,
#  'good': 544,
#  'got': 555,
#  'gov': 714,
#  'graphene': 534,
#  'great': 62,
#  'grew': 510,
#  'grow': 457,
#  'had': 123,
#  'happy': 651,
#  'harris': 186,
#  'has': 47,
#  'hate': 316,
#  'hav': 268,
#  'have': 74,
#  'he': 85,
#  'headed': 444,
#  'health': 328,
#  'hear': 80,
#  'hearing': 711,
#  'help': 135,
#  'helplines': 362,
#  'her': 153,
#  'herbs': 126,
#  'here': 75,
#  'hereby': 530,
#  'heres': 581,
#  'hi': 77,
#  'hidden': 645,
#  'highland': 269,
#  'hillary': 494,
#  'him': 152,
#  'his': 167,
#  'holidays': 501,
#  'hometown': 447,
#  'hope': 519,
#  'hotel': 108,
#  'hotels': 248,
#  'household': 507,
#  'how': 72,
#  'huge': 672,
#  'human': 366,
#  'hunter': 650,
#  'i': 28,
#  'iambic': 623,
#  'ian': 419,
#  'ice': 339,
#  'if': 113,
#  'in': 19,
#  'including': 242,
#  'incredible': 634,
#  'information': 263,
#  'inks': 538,
#  'innovative': 448,
#  'insurance': 329,
#  'intel': 388,
#  'intelligence': 347,
#  'interface': 605,
#  'intern': 414,
#  'interns': 417,
#  'interview': 164,
#  'into': 127,
#  'invited': 348,
#  'is': 27,
#  'israel': 720,
#  'it': 22,
#  'its': 361,
#  'itunes': 693,
#  'jack': 552,
#  'james': 129,
#  'jess': 575,
#  'job': 315,
#  'jobs': 226,
#  'joe': 235,
#  'john': 517,
#  'join': 78,
#  'joint': 344,
#  'joseph': 231,
#  'journalist': 314,
#  'joy': 664,
#  'jude': 547,
#  'judging': 574,
#  'just': 38,
#  'k': 120,
#  'kane': 513,
#  'karpinski': 686,
#  'keeps': 629,
#  'know': 56,
#  'koreatown': 271,
#  'krewe': 378,
#  'la': 273,
#  'land': 455,
#  'landscape': 641,
#  'large': 198,
#  'later': 343,
#  'latest': 473,
#  'league': 169,
#  'learn': 37,
#  'less': 459,
#  'let': 125,
#  'lies': 207,
#  'life': 516,
#  'like': 81,
#  'likes': 310,
#  'listen': 254,
#  'literally': 373,
#  'little': 579,
#  'live': 114,
#  'local': 499,
#  'log': 332,
#  'lol': 617,
#  'look': 140,
#  'looking': 276,
#  'lose': 678,
#  'love': 137,
#  'lth': 374,
#  'luck': 545,
#  'lucky': 669,
#  'm': 49,
#  'macron': 394,
#  'mainstream': 185,
#  'majority': 243,
#  'make': 42,
#  'man': 632,
#  'manager': 471,
#  'market': 540,
#  'match': 262,
#  'maximi': 475,
#  'may': 76,
#  'me': 165,
#  'measurement': 250,
#  'member': 294,
#  'memorial': 437,
#  'memories': 387,
#  'mention': 309,
#  'mentions': 308,
#  'merrill': 622,
#  'metrics': 592,
#  'michael': 402,
#  'mike': 122,
#  'minnesota': 222,
#  'mirror': 560,
#  'miss': 211,
#  'missiledefense': 258,
#  'modifications': 422,
#  'more': 40,
#  'morning': 482,
#  'mosen': 442,
#  'most': 465,
#  'move': 372,
#  'moves': 595,
#  'moving': 201,
#  'much': 454,
#  'multi': 99,
#  'musk': 628,
#  'my': 45,
#  'n': 451,
#  'nasa': 610,
#  'national': 255,
#  'nd': 178,
#  'nearly': 240,
#  'need': 149,
#  'needle': 202,
#  'needs': 371,
#  'negates': 602,
#  'nev': 671,
#  'new': 59,
#  'news': 87,
#  'no': 633,
#  'nobel': 612,
#  'not': 35,
#  'now': 103,
#  'of': 11,
#  'offered': 291,
#  'offers': 406,
#  'oil': 338,
#  'ok': 352,
#  'old': 689,
#  'olive': 337,
#  'on': 21,
#  'oncommand': 469,
#  'one': 68,
#  'online': 496,
#  'only': 290,
#  'open': 69,
#  'operating': 358,
#  'or': 303,
#  'order': 90,
#  'ordered': 463,
#  'ornament': 649,
#  'other': 302,
#  'others': 305,
#  'our': 32,
#  'ourselves': 304,
#  'out': 58,
#  'outdebate': 526,
#  'over': 60,
#  'p': 220,
#  'pahlka': 626,
#  'paper': 146,
#  'park': 270,
#  'passage': 700,
#  'pay': 563,
#  'peace': 613,
#  'pentameter': 624,
#  'per': 446,
#  'phil': 558,
#  'phillips': 292,
#  'pitches': 416,
#  'plan': 330,
#  'player': 288,
#  'please': 398,
#  'pls': 322,
#  'poetry': 621,
#  'pol': 683,
#  'polaris': 356,
#  'policy': 63,
#  'pop': 548,
#  'popcorn': 550,
#  'popovichkerr': 173,
#  'powered': 182,
#  'praises': 698,
#  'precision': 249,
#  'prepared': 668,
#  'presale': 116,
#  'presidential': 391,
#  'price': 261,
#  'prize': 614,
#  'processor': 377,
#  'producers': 676,
#  'product': 484,
#  'properties': 535,
#  'pros': 721,
#  'pruitt': 704,
#  'publi': 531,
#  'public': 188,
#  'purchase': 177,
#  'qs': 171,
#  'quality': 175,
#  'questions': 267,
#  'r': 619,
#  'ranch': 647,
#  'razorback': 286,
#  'rea': 532,
#  'reach': 79,
#  'read': 616,
#  'ready': 144,
#  'real': 151,
#  'really': 663,
#  'received': 363,
#  'record': 712,
#  'regards': 279,
#  'reid': 665,
#  'rejecting': 566,
#  'remember': 105,
#  'reminiscing': 282,
#  'reported': 174,
#  'reports': 364,
#  'researchers': 536,
#  'responsive': 708,
#  'restraining': 554,
#  'restrictive': 681,
#  'retweet': 312,
#  'retweets': 311,
#  'revolutionize': 191,
#  'rewrite': 702,
#  'rob': 696,
#  'robert': 480,
#  'rooms': 241,
#  'runner': 379,
#  'ryder': 479,
#  's': 73,
#  'sacrilege': 723,
#  'safety': 601,
#  'sales': 503,
#  'sanchez': 481,
#  'sandberg': 209,
#  'say': 156,
#  'school': 187,
#  'scienc': 453,
#  'security': 256,
#  'see': 121,
#  'self': 91,
#  'selfies': 564,
#  'semiautomatic': 425,
#  'senate': 346,
#  'sent': 644,
#  'service': 410,
#  'session': 638,
#  'she': 159,
#  'sheryl': 208,
#  'shirt': 658,
#  'shoes': 543,
#  'should': 351,
#  'show': 427,
#  'shows': 673,
#  'signed': 715,
#  'since': 355,
#  'smart': 136,
#  'snap': 299,
#  'snark': 300,
#  'snotty': 319,
#  'so': 400,
#  'software': 181,
#  'solution': 197,
#  'some': 549,
#  'something': 580,
#  'soon': 541,
#  'sorry': 67,
#  'splitting': 215,
#  'spotify': 691,
#  'st': 546,
#  'standing': 522,
#  'star': 247,
#  'starting': 607,
#  'state': 172,
#  'statement': 345,
#  'stay': 476,
#  'stem': 608,
#  'still': 694,
#  'stocks': 424,
#  'story': 138,
#  'storyline': 514,
#  'studies': 571,
#  'such': 205,
#  'summer': 412,
#  'summit': 584,
#  'superbly': 667,
#  'support': 141,
#  'swedish': 369,
#  'symantec': 635,
#  'systems': 253,
#  't': 657,
#  'tax': 701,
#  'tc': 295,
#  'team': 61,
#  'ten': 359,
#  'terrible': 603,
#  'tesla': 353,
#  'testify': 350,
#  'than': 460,
#  'thank': 84,
#  'thanks': 71,
#  'that': 18,
#  'the': 5,
#  'their': 376,
#  'there': 134,
#  'these': 82,
#  'they': 64,
#  'things': 320,
#  'think': 461,
#  'thinkers': 449,
#  'this': 31,
#  'those': 606,
#  'thrilled': 565,
#  'through': 236,
#  'thus': 529,
#  'time': 283,
#  'timeline': 587,
#  'tip': 333,
#  'to': 4,
#  'today': 94,
#  'togeth': 306,
#  'tomorrow': 225,
#  'too': 145,
#  'touched': 653,
#  'tour': 436,
#  'toys': 505,
#  'trade': 682,
#  'traffic': 367,
#  'traktor': 375,
#  'trays': 341,
#  'trouble': 213,
#  'trump': 161,
#  'trying': 630,
#  'tuesday': 334,
#  'tuned': 477,
#  'turn': 142,
#  'tweeps': 468,
#  'tweet': 318,
#  'tweeted': 434,
#  'twitter': 118,
#  'tx': 713,
#  'under': 679,
#  'undercover': 486,
#  'underway': 327,
#  'unified': 470,
#  'unique': 395,
#  'university': 221,
#  'up': 43,
#  'us': 46,
#  'use': 48,
#  'using': 568,
#  'v': 467,
#  'valentine': 518,
#  'valley': 646,
#  'version': 728,
#  'versus': 432,
#  'very': 162,
#  'via': 139,
#  'video': 131,
#  'violated': 553,
#  'virtual': 583,
#  'visit': 102,
#  'vogue': 381,
#  'volvo': 597,
#  'vote': 115,
#  'voters': 170,
#  'w': 533,
#  'wait': 497,
#  'want': 88,
#  'was': 692,
#  'washington': 680,
#  'waste': 335,
#  'watch': 478,
#  'way': 216,
#  'we': 25,
#  'weapons': 143,
#  'web': 727,
#  'week': 119,
#  'went': 596,
#  'were': 652,
#  'wfd': 462,
#  'what': 36,
#  'when': 44,
#  'where': 441,
#  'who': 643,
#  'whoops': 684,
#  'why': 155,
#  'will': 264,
#  'wilson': 232,
#  'winners': 615,
#  'wisdom': 158,
#  'with': 30,
#  'woodall': 697,
#  'working': 695,
#  'works': 331,
#  'would': 55,
#  'xc': 598,
#  'xerox': 230,
#  'xhp': 195,
#  'xmas': 648,
#  'yeah': 433,
#  'year': 659,
#  'years': 133,
#  'yesterday': 585,
#  'you': 12,
#  'your': 29,
#  'yours': 313,
#  'ys': 620,
#  '🍻': 420,
#  '🎉': 307}

# %%
# !mkdir data/lang_model

# %%
# save word index
import json
with open('data/lang_model/word_index.json', 'w') as fp:
    json.dump(tokenizer.word_index, fp)

# %%
# save sorted words
import operator
sorted_words = sorted(tokenizer.word_index.items(), key=operator.itemgetter(1))
sorted_words = [w[0] for w in sorted_words]
sorted_words = ['<unknown>'] + sorted_words
sorted_words[:10]
# Out:
# ['<unknown>',
#  '<url>',
#  '.',
#  '<user>',
#  'to',
#  'the',
#  '<allcaps>',
#  '<hashtag>',
#  '<number>',
#  '<repeat>']

# %%
from tep.utils import save_as_text
save_as_text(sorted_words, 'data/lang_model/word_labels.tsv')

# %% [markdown]
# ## Create sequences

# %%
seqs = tokenizer.texts_to_sequences(texts)
seqs
# Out:
# [[7, 8, 3, 3, 1],
#  [3, 25, 88, 4, 89, 31, 60, 4, 32, 61, 20, 42, 43, 14, 18, 2, 8, 8],
#  [5, 8, 10, 90, 44, 91, 10, 92, 10, 1, 1],
#  [62, 93, 94, 33, 5, 11, 63, 16, 1],
#  [3, 26, 35, 64, 38, 17],
#  [36, 27, 29, 95, 96, 17, 29, 7, 33, 7, 6, 6, 1, 1],
#  [97, 8, 98, 8, 6, 99, 10, 4, 19, 65, 1, 1],
#  [66, 5, 15, 1],
#  [3],
#  [64, 26, 2, 9, 1],
#  [21, 6, 33, 8, 39, 35, 22, 2, 1],
#  [3, 32, 20, 67, 14, 5, 2],
#  [3, 3, 3, 3, 27, 68, 4, 42, 29, 2, 45, 2, 9, 1],
#  [46, 33, 5, 11, 4, 37, 40, 34, 32, 69, 15, 2, 9, 1],
#  [12, 26, 5, 68, 22, 2, 1, 7, 7],
#  [1],
#  [94, 25, 6, 70, 2, 21, 31, 19, 8, 71, 14, 2, 1],
#  [3, 16, 5, 6, 47, 8, 5, 11, 10, 20, 10, 8, 8],
#  [37, 40, 34, 72, 4, 48, 4, 6, 16, 1, 2, 1],
#  [4, 11, 7, 16, 1, 7, 68, 73, 49, 98, 1],
#  [3, 25, 74, 5, 75, 14, 12, 2, 22, 12, 76, 2, 9, 1],
#  [12, 19, 6, 50, 6, 6],
#  [3, 77, 15, 25, 26, 14, 12, 22, 15, 2, 10, 6],
#  [28, 34, 45, 51, 7, 7, 30, 3, 2, 1],
#  [3, 22, 14, 31, 93, 5, 27, 5, 2, 2, 10, 6],
#  [25, 52, 48, 4, 20, 33, 4, 53, 19, 20, 78, 2, 9, 1],
#  [45, 21, 16, 8, 8, 79, 8, 8, 8, 79, 2, 30, 2, 9, 1],
#  [3, 3, 12, 26, 13, 2, 29, 27, 4, 20, 2],
#  [3, 77, 67, 4, 80, 12, 18, 2, 31, 14, 10, 43, 16, 1, 71],
#  [69, 27, 2, 4, 53, 13, 18, 14, 12, 21, 4, 2, 9, 1],
#  [7, 39, 35, 29, 50, 4, 15, 23, 24, 23, 24, 14, 1],
#  [1, 1],
#  [30, 3, 16, 5, 47, 4, 19, 69, 23, 24, 70, 2, 9, 1],
#  [3, 28, 2],
#  [11, 91, 10, 92, 19, 1],
#  [60, 74, 11, 8, 11, 2, 9, 1],
#  [44, 51, 4, 6, 23, 24, 97, 99, 10, 26, 4, 16, 2, 9, 1],
#  [43, 11, 5, 6, 18, 30, 16, 2, 9, 1],
#  [1, 3],
#  [3,
#   25,
#   26,
#   54,
#   29,
#   23,
#   24,
#   55,
#   81,
#   4,
#   22,
#   2,
#   52,
#   12,
#   46,
#   33,
#   8,
#   8,
#   8,
#   25,
#   52,
#   37,
#   40,
#   17],
#  [3, 3],
#  [3, 3, 12, 56, 18, 64, 20, 2, 9, 1],
#  [8, 11, 32, 7, 11, 96, 15, 7, 1],
#  [3, 4, 18, 15],
#  [8, 10, 10, 81, 10, 10, 18, 19, 1],
#  [3, 14, 31, 4, 57],
#  [74, 13, 17, 37, 36, 29, 63, 76, 29, 63, 16, 1, 1],
#  [3, 18],
#  [3, 16, 1],
#  [4, 78, 3, 23, 24, 3, 21, 13, 4, 1],
#  [3, 26, 82, 17],
#  [7, 6, 6, 35, 4, 6, 5, 2, 1],
#  [37, 34, 32, 61, 11, 15, 46, 33, 7, 49, 13, 13, 8, 8, 20, 53, 5, 2, 9, 1],
#  [72, 27, 4, 32, 17, 12, 76, 2, 7, 6, 6, 8, 1],
#  [15, 1],
#  [15, 42, 5, 11, 5, 15, 7, 13, 1],
#  [88, 4, 56, 40, 34, 17, 58, 3, 21, 72, 12, 52, 48, 22, 4, 2, 9, 1],
#  [4, 6, 21, 3, 31, 8, 41, 2, 7, 59, 7],
#  [19, 11, 5, 2, 2, 9, 1],
#  [36, 17, 17, 1],
#  [4, 13, 19, 5, 32, 61, 23, 24, 2, 9, 1],
#  [3, 11, 28, 39, 15, 43, 21, 15],
#  [3, 77, 15, 32, 13, 10, 11, 83, 5, 8, 73, 2, 12, 81, 22, 2, 10],
#  [28, 41, 38, 13, 19, 11, 13, 4, 33, 13, 2, 28, 41, 2, 9, 1],
#  [3, 31, 27, 5, 28, 65, 1],
#  [7, 26, 23, 24, 4, 79, 5, 16, 2, 9, 1],
#  [3, 3],
#  [3, 25, 82, 15, 20, 84, 12, 14, 12, 39, 4, 2, 15],
#  [20, 21, 3, 15, 10, 3, 1],
#  [18, 85, 47, 5, 90, 85, 17, 7, 1],
#  [16, 19, 5, 35, 10, 10, 12, 14, 30, 2],
#  [3, 4, 80, 12, 26, 5, 20, 5, 11, 10, 15],
#  [3, 3, 28, 27, 54, 65],
#  [3, 12, 56, 36, 55, 50, 62, 30, 29, 7, 17, 2, 20, 6, 46, 14, 13, 2, 7, 4],
#  [36, 3, 23, 24, 3, 19, 3, 17, 53, 58, 75, 16, 1, 7],
#  [13, 11, 20, 21, 6, 60, 5, 16, 1],
#  [3, 71, 14, 5, 2, 25, 5, 19, 5, 6, 55, 18, 42, 22, 17],
#  [1],
#  [3, 3, 2, 28, 30, 13, 6, 8, 13, 19, 10],
#  [83, 38, 58, 19, 7, 6, 6, 4, 7, 6, 6, 7, 23, 24, 7, 40, 34, 82, 2, 9, 1],
#  [3, 3, 1],
#  [7, 13, 49, 49, 1],
#  [86, 86, 86, 28, 12, 45, 2, 62, 30, 13, 2, 9, 1],
#  [4, 89, 4, 50, 4, 2, 84, 12, 2, 36, 51, 1, 3],
#  [3, 2, 66],
#  [78, 3, 33, 7, 73, 70, 2, 37, 34, 21, 5, 16, 2, 9, 1],
#  [28, 4, 56, 31, 1],
#  [3, 84, 12, 2, 25, 26, 4, 80, 12, 54, 32, 30, 3, 2],
#  [25, 26, 29, 7, 10, 13, 59, 14, 13, 59, 15, 29, 14, 13, 16, 1],
#  [38, 18, 17, 1],
#  [11, 3, 27, 23, 24, 66, 2, 44, 28, 41, 4, 57, 21, 5, 30, 6, 2, 9, 1],
#  [2, 1],
#  [59, 95, 18, 6, 4, 58, 2, 9, 1],
#  [67, 18, 11, 11, 35, 11, 2, 18, 55, 57, 87, 2],
#  [28, 41, 4, 44, 5, 34, 13, 14, 87, 34, 51, 14, 87, 2, 20, 22, 27, 35, 2, 9],
#  [11, 54, 1],
#  [47, 23, 24, 4, 57, 4, 31, 2, 85, 8, 23, 24, 8, 14, 5, 3],
#  [6, 2, 38, 30, 18, 2, 75, 21, 22, 83, 10, 2, 9, 1],
#  [27, 22, 4, 16, 39, 25, 14, 17, 27, 35, 22, 4, 48, 5, 17, 1],
#  [2, 1]]

# %%
seq_lens = [len(s) for s in seqs]

# %%
# calculate 90th percentile
import numpy as np

percentiles = [90, 95, 99, 100]
for p in percentiles:
    print('{}th percentile:'.format(p), int(np.round(np.percentile(seq_lens, p))))
# Out:
# 90th percentile: 16
# 95th percentile: 19
# 99th percentile: 21
# 100th percentile: 24

# %%
max_len = 21
padded_seqs = pad_sequences(seqs, maxlen=max_len)

# %%
from tep.utils import save_array

# %%
save_array(padded_seqs, 'data/lang_model/seqs.bc')

# %% [markdown]
# ## Create inputs and labels

# %%
input_seqs = []
for seq in seqs:
    for i in range(1, len(seq)):
        n_gram_seq = seq[:i+1]
        input_seqs.append(n_gram_seq)

# %%
padded_input_seqs = np.array(pad_sequences(input_seqs, maxlen=max_len))

# %%
inputs, labels = padded_input_seqs[:,:-1], padded_input_seqs[:,-1]

# %%
import keras.utils as ku

# %%
labels = ku.to_categorical(labels, num_classes=(num_words+1))

# %%
save_array(inputs, 'data/lang_model/inputs.bc')
save_array(labels, 'data/lang_model/labels.bc')

# %% [markdown]
# ## Create embedding matrix

# %%
# generate embeddings index
f = open('glove/glove.twitter.27B.200d.txt', encoding='utf-8')
embeddings_index = {}
for line in f:
    vals = line.split()
    word = vals[0]
    coeffs = np.asarray(vals[1:], dtype='float32')
    embeddings_index[word] = coeffs
f.close()

# %%
# fill embedding matrix
embedding_matrix = np.zeros((num_words + 1, embedding_dimension))
for word, i in tokenizer.word_index.items():
    emb_vec = embeddings_index.get(word)
    if emb_vec is not None and i <= num_words:
        embedding_matrix[i] = emb_vec

# %%
save_array(embedding_matrix, 'data/lang_model/emb_mat.bc')

# %% [markdown]
# ## Conclusion

# %%
# !ls data/lang_model/
# Out:
# emb_mat.bc      labels.bc       word_index.json
# inputs.bc       seqs.bc         word_labels.tsv
